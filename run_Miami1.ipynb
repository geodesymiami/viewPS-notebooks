# %% [markdown]
# ## Summary Miami/Surfside
# This notebook does multiple calls of `view_persistent_scatterers.py` to visualize the displacement history. For options see `viewPS.py --help`. Modify the `cmd` line to test plot options.

# %%
import sys
import os
from cli import view_persistent_scatterers

# %%
#%%capture --no-display
######################################################
os.chdir(os.getenv('SCRATCHDIR') + '/MiamiSenAT48/miaplpy_MDCBeach_201901_202306/network_single_reference')
cmd = 'view_persistent_scatterers.py velocity.h5 --mask ../maskPS.h5 --subset-lalo 25.8755:25.879,-80.1226:-80.1205' 
sys.argv = cmd.split()
view_persistent_scatterers.main(sys.argv)
# Out:
# 20240117:164026 * view_persistent_scatterers.py velocity.h5 --mask ../maskPS.h5 --subset-lalo 25.8755:25.879,-80.1226:-80.1205

# %%
# !view_persistent_scatterers.py velocity.h5 --mask ../maskPS.h5 --subset-lalo 25.8755:25.879,-80.1226:-80.1205
# Out:
# 20240117:164957 * view_persistent_scatterers.py velocity.h5 --mask ../maskPS.h5 --subset-lalo 25.8755:25.879,-80.1226:-80.1205
# Figure(500x1000)

# %%
# !view_persistent_scatterers.py --help
# Out:
# 20240117:164029 * view_persistent_scatterers.py --help
# usage: view_persistent_scatterers.py [-h] --subset-lalo SUBSET_LALO
#                                      [--mask FILE] [--geometry-file FILE]
#                                      [--ref-lalo LAT LON] [--dem-offset NUM]
#                                      [--estimated-elevation] [--backscatter]
#                                      [--geotiff FILE] [--out-amplitude FILE]
#                                      [--vlim VMIN VMAX] [--flip-lr]
#                                      [--flip-ud] [--colormap]
#                                      [--point-size NUM] [--fontsize]
#                                      [--figsize WID LEN] [-o OUTFILE] [--save]
#                                      [--dpi DPI] [--nodisplay]
#                                      [--nowhitespace]
#                                      data_file
#
# Plots velocity, DEM error or estimated elevation on open_street_map, geoTiff or backscatter.
#
# ...
